# %%
from DataExtraction import *

# %%
path = "F:/Sorteret Rå Data/Samlede datafiler/Compression"
main2(path, stress_strain=True, figsize=(20,45), savefig=True, figname="COWI Test Plots")
# Out:
# Found 10 files in the target directory. Processing...
# c:\Users\peter\OneDrive\Dokumenter\GitHub\cowi_data_extraction\DataExtraction.py:316: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   i.legend(loc='upper right', fontsize='small')
# Saved figure as compression_test_plots.png
