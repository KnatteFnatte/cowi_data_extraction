# %%
from DataExtraction import collect_csv, get_directories, get_filenames
import os

# %%
directory = "C:/Users/pris/OneDrive - Danmarks Tekniske Universitet/Dokumenter/Cowi_Data/Sorteret Rå Data/Compression"
os.chdir(directory)
directory_list = get_directories(directory)
for i in directory_list:
    print("currently in directory "+i)
    file_list = get_filenames(i)
    print(file_list)
    collect_csv(i)
# Out:
# currently in directory C:/Users/pris/OneDrive - Danmarks Tekniske Universitet/Dokumenter/Cowi_Data/Sorteret Rå Data/Compression/folder/ERS_S15_W11.6_Cu28-C23
# ['ERS_S15_W11.6_Cu28-C23_1.txt', 'ERS_S15_W11.6_Cu28-C23_2.txt', 'ERS_S15_W11.6_Cu28-C23_3.txt']
# ['ERS', 'S15', 'W11.6', 'Cu28-C23', '1']
# ERS_S15_W11.6_Cu28-C23.csv
# C:\Users\pris\OneDrive - Danmarks Tekniske Universitet\Dokumenter\Cowi_Data\Sorteret Rå Data\Compression\folder
# C:\Users\pris\OneDrive - Danmarks Tekniske Universitet\Dokumenter\Cowi_Data\Sorteret Rå Data\Compression\folder
# currently in directory C:/Users/pris/OneDrive - Danmarks Tekniske Universitet/Dokumenter/Cowi_Data/Sorteret Rå Data/Compression/folder/ERS_S15_W11.6_Cu28-C23_Reco-W12.9
# ['ERS_S15_W11.6_Cu28-C23_Reco-W12.9_1.txt', 'ERS_S15_W11.6_Cu28-C23_Reco-W12.9_2.txt', 'ERS_S15_W11.6_Cu28-C23_Reco-W12.9_3.txt', 'ERS_S15_W11.6_Cu28-C23_Reco-W12.9_4.txt']
# ['ERS', 'S15', 'W11.6', 'Cu28-C23', 'Reco-W12.9', '1']
# ...
