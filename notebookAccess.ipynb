# %%
from DataExtraction import merge_output_files

# %%
merge_output_files("output3.csv", ["output.csv", "output2.csv"])
# Out:
#   Clay type Sand content Water content Lime content  Curing  Drying  \
# 0       ERS          S15         W15.8           L5    True   False
# 1       ERS          S15         W15.8           L5    True   False
# 2       ERS          S15         W15.8           L5    True   False
# 3       ERS          S15         W15.8           L5    True   False
#
#   Temperature   CO2  Recompression  New WC
# 0         C40  True          False     NaN
# 1         C40  True          False     NaN
# 2         C40  True          False     NaN
# 3         C40  True          False     NaN
